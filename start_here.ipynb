# %%
# Download the pretrained model of dlib
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Extract it and extract it
# !bzip2 -dk /content/shape_predictor_68_face_landmarks.dat.bz2 # if -k argument is not provided it will not preserve source file
# And pass the path to the RefFaceSwapping
# Out:
# --2022-03-27 05:45:43--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2.2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  76.3MB/s    in 0.8s
#
# 2022-03-27 05:45:43 (76.3 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2.2’ saved [64040097/64040097]
#
# bzip2: Output file /content/shape_predictor_68_face_landmarks.dat already exists.

# %%
# cv2.MIXED_CLONE is used at  ref_swap.py file which is more efficient is gradient handling
# see line no 77 of ref_swap.py

# %%
# !git clone https://github.com/Tismoney/FaceSwapping.git
# %cp -r /content/FaceSwapping/* /content
# Out:
# fatal: destination path 'FaceSwapping' already exists and is not an empty directory.

# %%
# %load_ext autoreload
# %autoreload 2
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

from fswap import RefFaceSwapping , TwoFaceSwapping
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
face_swapping = RefFaceSwapping(reference_path='/content/imgs/reference.png', predictor_path='/content/shape_predictor_68_face_landmarks.dat')
img = face_swapping.load_img('/content/imgs/img.png')
img_swap = face_swapping(img)

# %%
_, ax = plt.subplots(1, 2, figsize=(25, 20))
ax[0].imshow(img)
ax[1].imshow(img_swap)
ax[0].axis(False)
ax[1].axis(False)
plt.show()
